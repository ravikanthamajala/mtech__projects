# %% [markdown]
# ## 1.Load Gensim Lib

# %%
# !pip install gensim --quiet

# %%
import gensim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data: https://www.kaggle.com/c/word2vec-nlp-tutorial/data

# %%
df=pd.read_csv('/content/drive/MyDrive/HGN/NLP By HGN/NLP for SRM /HGN/unit2/labeledTrainData.tsv.zip',header=0,delimiter='\t')

# %%
df.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
df.shape
# Out:
# (25000, 3)

# %%
df.loc[0,"review"]
# Out:
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci's character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ's music.<br /><br />Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.<br /><br />Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ's bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i've gave this subject....hmmm well i don't know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."

# %%
import re, string

def clean_str(string):
  try:
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)
    words = string.strip().lower().split()
    words = [w for w in words if len(w)>=1]
    return " ".join(words)
  except:
    return " "

# %% [markdown]
# Removing URLs (though the regex pattern is incorrect).
# Removing non-alphabetic characters.
# Converting to lowercase.
# Splitting words and removing empty entries.

# %%
df['clean_review'] = df['review'].apply(clean_str)
df.head()
# Out:
#        id  sentiment                                             review  \
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
#
#                                         clean_review
# 0  with all this stuff going down at the moment w...
# 1  the classic war of the worlds by timothy hines...
# 2  the film starts with a manager nicholas bell g...
# 3  it must be assumed that those who praised this...
# 4  superbly trashy and wondrously unpretentious s...

# %% [markdown]
# ### convert review to word list

# %%
documents = []

for doc in df['clean_review']:
  documents.append(doc.split(' '))

# %%
print(len(documents))
# Out:
# 25000

# %%
print(documents[0])
# Out:
# ['with', 'all', 'this', 'stuff', 'going', 'down', 'at', 'the', 'moment', 'with', 'mj', 'i', 've', 'started', 'listening', 'to', 'his', 'music', 'watching', 'the', 'odd', 'documentary', 'here', 'and', 'there', 'watched', 'the', 'wiz', 'and', 'watched', 'moonwalker', 'again', 'maybe', 'i', 'just', 'want', 'to', 'get', 'a', 'certain', 'insight', 'into', 'this', 'guy', 'who', 'i', 'thought', 'was', 'really', 'cool', 'in', 'the', 'eighties', 'just', 'to', 'maybe', 'make', 'up', 'my', 'mind', 'whether', 'he', 'is', 'guilty', 'or', 'innocent', 'moonwalker', 'is', 'part', 'biography', 'part', 'feature', 'film', 'which', 'i', 'remember', 'going', 'to', 'see', 'at', 'the', 'cinema', 'when', 'it', 'was', 'originally', 'released', 'some', 'of', 'it', 'has', 'subtle', 'messages', 'about', 'mj', 's', 'feeling', 'towards', 'the', 'press', 'and', 'also', 'the', 'obvious', 'message', 'of', 'drugs', 'are', 'bad', 'm', 'kay', 'br', 'br', 'visually', 'impressive', 'but', 'of', 'course', 'this', 'is', 'all', 'about', 'michael', 'jackson', 'so', 'unless', 'you', 'remotely', 'like', 'mj', 'in', 'anyway', 'then', 'you', 'are', 'going', 'to', 'hate', 'this', 'and', 'find', 'it', 'boring', 'some', 'may', 'call', 'mj', 'an', 'egotist', 'for', 'consenting', 'to', 'the', 'making', 'of', 'this', 'movie', 'but', 'mj', 'and', 'most', 'of', 'his', 'fans', 'would', 'say', 'that', 'he', 'made', 'it', 'for', 'the', 'fans', 'which', 'if', 'true', 'is', 'really', 'nice', 'of', 'him', 'br', 'br', 'the', 'actual', 'feature', 'film', 'bit', 'when', 'it', 'finally', 'starts', 'is', 'only', 'on', 'for', 'minutes', 'or', 'so', 'excluding', 'the', 'smooth', 'criminal', 'sequence', 'and', 'joe', 'pesci', 'is', 'convincing', 'as', 'a', 'psychopathic', 'all', 'powerful', 'drug', 'lord', 'why', 'he', 'wants', 'mj', 'dead', 'so', 'bad', 'is', 'beyond', 'me', 'because', 'mj', 'overheard', 'his', 'plans', 'nah', 'joe', 'pesci', 's', 'character', 'ranted', 'that', 'he', 'wanted', 'people', 'to', 'know', 'it', 'is', 'he', 'who', 'is', 'supplying', 'drugs', 'etc', 'so', 'i', 'dunno', 'maybe', 'he', 'just', 'hates', 'mj', 's', 'music', 'br', 'br', 'lots', 'of', 'cool', 'things', 'in', 'this', 'like', 'mj', 'turning', 'into', 'a', 'car', 'and', 'a', 'robot', 'and', 'the', 'whole', 'speed', 'demon', 'sequence', 'also', 'the', 'director', 'must', 'have', 'had', 'the', 'patience', 'of', 'a', 'saint', 'when', 'it', 'came', 'to', 'filming', 'the', 'kiddy', 'bad', 'sequence', 'as', 'usually', 'directors', 'hate', 'working', 'with', 'one', 'kid', 'let', 'alone', 'a', 'whole', 'bunch', 'of', 'them', 'performing', 'a', 'complex', 'dance', 'scene', 'br', 'br', 'bottom', 'line', 'this', 'movie', 'is', 'for', 'people', 'who', 'like', 'mj', 'on', 'one', 'level', 'or', 'another', 'which', 'i', 'think', 'is', 'most', 'people', 'if', 'not', 'then', 'stay', 'away', 'it', 'does', 'try', 'and', 'give', 'off', 'a', 'wholesome', 'message', 'and', 'ironically', 'mj', 's', 'bestest', 'buddy', 'in', 'this', 'movie', 'is', 'a', 'girl', 'michael', 'jackson', 'is', 'truly', 'one', 'of', 'the', 'most', 'talented', 'people', 'ever', 'to', 'grace', 'this', 'planet', 'but', 'is', 'he', 'guilty', 'well', 'with', 'all', 'the', 'attention', 'i', 've', 'gave', 'this', 'subject', 'hmmm', 'well', 'i', 'don', 't', 'know', 'because', 'people', 'can', 'be', 'different', 'behind', 'closed', 'doors', 'i', 'know', 'this', 'for', 'a', 'fact', 'he', 'is', 'either', 'an', 'extremely', 'nice', 'but', 'stupid', 'guy', 'or', 'one', 'of', 'the', 'most', 'sickest', 'liars', 'i', 'hope', 'he', 'is', 'not', 'the', 'latter']

# %%
model=gensim.models.Word2Vec(documents,# List of tokenized sentences
                             min_count=10,# Ignore words appearing less than 10 times
                             workers=4,# Number of CPU cores for training
                             vector_size=50,# Dimension of word embeddings
                             window=5,# Context window size
                             epochs=10)# Number of training iterations

# %% [markdown]
# ### Exploring the model

# %%
model.wv.vectors.shape
# Out:
# (19874, 50)

# %%
model.wv.key_to_index
# Out:
# {'the': 0,
#  'and': 1,
#  'a': 2,
#  'of': 3,
#  'to': 4,
#  'is': 5,
#  'br': 6,
#  'it': 7,
#  'in': 8,
#  'i': 9,
#  'this': 10,
#  'that': 11,
#  's': 12,
#  'was': 13,
#  'as': 14,
#  'for': 15,
#  'with': 16,
#  'movie': 17,
#  'but': 18,
#  'film': 19,
#  't': 20,
#  'you': 21,
#  'on': 22,
#  'not': 23,
#  'he': 24,
#  'are': 25,
#  'his': 26,
#  'have': 27,
#  'be': 28,
#  'one': 29,
#  'all': 30,
#  'at': 31,
#  'they': 32,
#  'by': 33,
#  'an': 34,
#  'who': 35,
#  'so': 36,
#  'from': 37,
#  'like': 38,
#  'there': 39,
#  'her': 40,
#  'or': 41,
#  'just': 42,
#  'about': 43,
#  'out': 44,
#  'if': 45,
#  'has': 46,
#  'what': 47,
#  'some': 48,
#  'good': 49,
#  'can': 50,
#  'more': 51,
#  'she': 52,
#  'when': 53,
#  'very': 54,
#  'up': 55,
#  'time': 56,
#  'no': 57,
#  'even': 58,
#  'my': 59,
#  'would': 60,
#  'which': 61,
#  'story': 62,
#  'only': 63,
#  'really': 64,
#  'see': 65,
#  'their': 66,
#  'had': 67,
#  'we': 68,
#  'were': 69,
#  'me': 70,
#  'well': 71,
#  'than': 72,
#  'much': 73,
#  'get': 74,
#  'bad': 75,
#  'been': 76,
#  'people': 77,
#  'will': 78,
#  'do': 79,
#  'other': 80,
#  'also': 81,
#  'into': 82,
#  'first': 83,
#  'great': 84,
#  'because': 85,
#  'how': 86,
#  'him': 87,
#  'don': 88,
#  'most': 89,
#  'made': 90,
#  'its': 91,
#  'then': 92,
#  'way': 93,
#  'make': 94,
#  'them': 95,
#  'could': 96,
#  'too': 97,
#  'movies': 98,
#  'any': 99,
#  'after': 100,
#  'think': 101,
#  'characters': 102,
#  'character': 103,
#  'watch': 104,
#  'two': 105,
#  'films': 106,
#  'seen': 107,
#  'many': 108,
#  'life': 109,
#  'being': 110,
#  'plot': 111,
#  'acting': 112,
#  'never': 113,
#  'love': 114,
#  'little': 115,
#  'best': 116,
#  'where': 117,
#  'over': 118,
#  'did': 119,
#  'show': 120,
#  'know': 121,
#  'off': 122,
#  'ever': 123,
#  'man': 124,
#  'does': 125,
#  'here': 126,
#  'better': 127,
#  'your': 128,
#  'end': 129,
#  'still': 130,
#  'these': 131,
#  'say': 132,
#  'scene': 133,
#  'why': 134,
#  'while': 135,
#  'scenes': 136,
#  've': 137,
#  'go': 138,
#  'such': 139,
#  'm': 140,
#  'something': 141,
#  'should': 142,
#  'back': 143,
#  'through': 144,
#  'real': 145,
#  'those': 146,
#  'watching': 147,
#  'now': 148,
#  're': 149,
#  'though': 150,
#  'doesn': 151,
#  'thing': 152,
#  'old': 153,
#  'years': 154,
#  'actors': 155,
#  'director': 156,
#  'work': 157,
#  'didn': 158,
#  'another': 159,
#  'before': 160,
#  'new': 161,
#  'nothing': 162,
#  'funny': 163,
#  'actually': 164,
#  'makes': 165,
#  'look': 166,
#  'find': 167,
#  'going': 168,
#  'few': 169,
#  'same': 170,
#  'part': 171,
#  'again': 172,
#  'lot': 173,
#  'every': 174,
#  'world': 175,
#  'cast': 176,
#  'us': 177,
#  'quite': 178,
#  'down': 179,
#  'want': 180,
#  'things': 181,
#  'pretty': 182,
#  'young': 183,
#  'seems': 184,
#  'around': 185,
#  'horror': 186,
#  'got': 187,
#  'however': 188,
#  'fact': 189,
#  'take': 190,
#  'big': 191,
#  'enough': 192,
#  'long': 193,
#  'thought': 194,
#  'series': 195,
#  'both': 196,
#  'between': 197,
#  'may': 198,
#  'original': 199,
#  'give': 200,
#  'd': 201,
#  'action': 202,
#  'own': 203,
#  'right': 204,
#  'without': 205,
#  'must': 206,
#  'comedy': 207,
#  'always': 208,
#  'times': 209,
#  'point': 210,
#  'gets': 211,
#  'family': 212,
#  'come': 213,
#  'role': 214,
#  'isn': 215,
#  'saw': 216,
#  'almost': 217,
#  'interesting': 218,
#  'least': 219,
#  'done': 220,
#  'whole': 221,
#  'music': 222,
#  'bit': 223,
#  'guy': 224,
#  'script': 225,
#  'far': 226,
#  'making': 227,
#  'minutes': 228,
#  'feel': 229,
#  'anything': 230,
#  'last': 231,
#  'might': 232,
#  'since': 233,
#  'll': 234,
#  'performance': 235,
#  'girl': 236,
#  'probably': 237,
#  'am': 238,
#  'woman': 239,
#  'kind': 240,
#  'tv': 241,
#  'away': 242,
#  'yet': 243,
#  'day': 244,
#  'rather': 245,
#  'worst': 246,
#  'fun': 247,
#  'sure': 248,
#  'hard': 249,
#  'anyone': 250,
#  'played': 251,
#  'each': 252,
#  'found': 253,
#  'having': 254,
#  'although': 255,
#  'especially': 256,
#  'our': 257,
#  'course': 258,
#  'believe': 259,
#  'screen': 260,
#  'comes': 261,
#  'looking': 262,
#  'trying': 263,
#  'set': 264,
#  'goes': 265,
#  'book': 266,
#  'looks': 267,
#  'place': 268,
#  'actor': 269,
#  'different': 270,
#  'put': 271,
#  'money': 272,
#  'year': 273,
#  'ending': 274,
#  'dvd': 275,
#  'let': 276,
#  'maybe': 277,
#  'someone': 278,
#  'true': 279,
#  'once': 280,
#  'sense': 281,
#  'everything': 282,
#  'reason': 283,
#  'wasn': 284,
#  'shows': 285,
#  'three': 286,
#  'worth': 287,
#  'job': 288,
#  'main': 289,
#  'together': 290,
#  'play': 291,
#  'watched': 292,
#  'american': 293,
#  'everyone': 294,
#  'plays': 295,
#  'john': 296,
#  'effects': 297,
#  'later': 298,
#  'audience': 299,
#  'said': 300,
#  'takes': 301,
#  'instead': 302,
#  'house': 303,
#  'beautiful': 304,
#  'seem': 305,
#  'night': 306,
#  'high': 307,
#  'himself': 308,
#  'version': 309,
#  'wife': 310,
#  'during': 311,
#  'left': 312,
#  'father': 313,
#  'special': 314,
#  'seeing': 315,
#  'half': 316,
#  'star': 317,
#  'excellent': 318,
#  'war': 319,
#  'shot': 320,
#  'idea': 321,
#  'black': 322,
#  'nice': 323,
#  'less': 324,
#  'else': 325,
#  'mind': 326,
#  'simply': 327,
#  'read': 328,
#  'second': 329,
#  'fan': 330,
#  'death': 331,
#  'men': 332,
#  'hollywood': 333,
#  'poor': 334,
#  'help': 335,
#  'completely': 336,
#  'dead': 337,
#  'used': 338,
#  'home': 339,
#  'line': 340,
#  'short': 341,
#  'either': 342,
#  'given': 343,
#  'top': 344,
#  'kids': 345,
#  'budget': 346,
#  'try': 347,
#  'classic': 348,
#  'wrong': 349,
#  'performances': 350,
#  'women': 351,
#  'boring': 352,
#  'enjoy': 353,
#  'need': 354,
#  'use': 355,
#  'rest': 356,
#  'low': 357,
#  'friends': 358,
#  'production': 359,
#  'until': 360,
#  'full': 361,
#  'camera': 362,
#  'along': 363,
#  'truly': 364,
#  'video': 365,
#  'awful': 366,
#  'couple': 367,
#  'tell': 368,
#  'next': 369,
#  'remember': 370,
#  'stupid': 371,
#  'stars': 372,
#  'start': 373,
#  'sex': 374,
#  'perhaps': 375,
#  'won': 376,
#  'mean': 377,
#  'came': 378,
#  'recommend': 379,
#  'moments': 380,
#  'episode': 381,
#  'school': 382,
#  'wonderful': 383,
#  'small': 384,
#  'face': 385,
#  'understand': 386,
#  'terrible': 387,
#  'playing': 388,
#  'getting': 389,
#  'written': 390,
#  'early': 391,
#  'name': 392,
#  'doing': 393,
#  'style': 394,
#  'often': 395,
#  'keep': 396,
#  'perfect': 397,
#  'human': 398,
#  'person': 399,
#  'others': 400,
#  'definitely': 401,
#  'gives': 402,
#  'itself': 403,
#  'boy': 404,
#  'lost': 405,
#  'lines': 406,
#  'live': 407,
#  'become': 408,
#  'dialogue': 409,
#  'head': 410,
#  'piece': 411,
#  'finally': 412,
#  'yes': 413,
#  'case': 414,
#  'felt': 415,
#  'mother': 416,
#  'supposed': 417,
#  'liked': 418,
#  'children': 419,
#  'couldn': 420,
#  'title': 421,
#  'cinema': 422,
#  'white': 423,
#  'absolutely': 424,
#  'picture': 425,
#  'against': 426,
#  'sort': 427,
#  'worse': 428,
#  'certainly': 429,
#  'went': 430,
#  'entire': 431,
#  'waste': 432,
#  'killer': 433,
#  'problem': 434,
#  'oh': 435,
#  'mr': 436,
#  'evil': 437,
#  'hope': 438,
#  'entertaining': 439,
#  'friend': 440,
#  'overall': 441,
#  'called': 442,
#  'based': 443,
#  'loved': 444,
#  'fans': 445,
#  'several': 446,
#  'drama': 447,
#  'beginning': 448,
#  'lives': 449,
#  'direction': 450,
#  'care': 451,
#  'dark': 452,
#  'already': 453,
#  'becomes': 454,
#  'laugh': 455,
#  'example': 456,
#  'under': 457,
#  'despite': 458,
#  'seemed': 459,
#  'throughout': 460,
#  'turn': 461,
#  'son': 462,
#  'unfortunately': 463,
#  'wanted': 464,
#  'history': 465,
#  'michael': 466,
#  'final': 467,
#  'heart': 468,
#  'fine': 469,
#  'child': 470,
#  'amazing': 471,
#  'sound': 472,
#  'b': 473,
#  'humor': 474,
#  'guess': 475,
#  'lead': 476,
#  'totally': 477,
#  'guys': 478,
#  'writing': 479,
#  'quality': 480,
#  'close': 481,
#  'art': 482,
#  'wants': 483,
#  'game': 484,
#  'behind': 485,
#  'town': 486,
#  'works': 487,
#  'side': 488,
#  'tries': 489,
#  'days': 490,
#  'past': 491,
#  'viewer': 492,
#  'able': 493,
#  'flick': 494,
#  'hand': 495,
#  'genre': 496,
#  'act': 497,
#  'turns': 498,
#  'enjoyed': 499,
#  'today': 500,
#  'kill': 501,
#  'favorite': 502,
#  'car': 503,
#  'soon': 504,
#  'starts': 505,
#  'actress': 506,
#  'run': 507,
#  'sometimes': 508,
#  'eyes': 509,
#  'gave': 510,
#  'etc': 511,
#  'late': 512,
#  'girls': 513,
#  'god': 514,
#  'directed': 515,
#  'horrible': 516,
#  'kid': 517,
#  'city': 518,
#  'brilliant': 519,
#  'parts': 520,
#  'hour': 521,
#  'blood': 522,
#  'self': 523,
#  'themselves': 524,
#  'stories': 525,
#  'thinking': 526,
#  'expect': 527,
#  'stuff': 528,
#  'obviously': 529,
#  'decent': 530,
#  'voice': 531,
#  'writer': 532,
#  'highly': 533,
#  'fight': 534,
#  'myself': 535,
#  'feeling': 536,
#  'daughter': 537,
#  'slow': 538,
#  'except': 539,
#  'matter': 540,
#  'type': 541,
#  'age': 542,
#  'anyway': 543,
#  'roles': 544,
#  'moment': 545,
#  'heard': 546,
#  'killed': 547,
#  'says': 548,
#  'leave': 549,
#  'brother': 550,
#  'took': 551,
#  'strong': 552,
#  'cannot': 553,
#  'police': 554,
#  'violence': 555,
#  'hit': 556,
#  'stop': 557,
#  'happens': 558,
#  'known': 559,
#  'particularly': 560,
#  'involved': 561,
#  'happened': 562,
#  'extremely': 563,
#  'chance': 564,
#  'james': 565,
#  'obvious': 566,
#  'murder': 567,
#  'told': 568,
#  'living': 569,
#  'coming': 570,
#  'alone': 571,
#  'wouldn': 572,
#  'experience': 573,
#  'lack': 574,
#  'hero': 575,
#  'including': 576,
#  'attempt': 577,
#  'please': 578,
#  'happen': 579,
#  'gore': 580,
#  'crap': 581,
#  'wonder': 582,
#  'cut': 583,
#  'complete': 584,
#  'group': 585,
#  'ago': 586,
#  'interest': 587,
#  'none': 588,
#  'score': 589,
#  'husband': 590,
#  'david': 591,
#  'hell': 592,
#  'save': 593,
#  'simple': 594,
#  'ok': 595,
#  'looked': 596,
#  'song': 597,
#  'career': 598,
#  'number': 599,
#  'seriously': 600,
#  'possible': 601,
#  'king': 602,
#  'annoying': 603,
#  'sad': 604,
#  'exactly': 605,
#  'shown': 606,
#  'running': 607,
#  'musical': 608,
#  'yourself': 609,
#  'serious': 610,
#  'scary': 611,
#  'taken': 612,
#  'reality': 613,
#  'english': 614,
#  'released': 615,
#  'whose': 616,
#  'cinematography': 617,
#  'hours': 618,
#  'ends': 619,
#  'usually': 620,
#  'opening': 621,
#  'jokes': 622,
#  'light': 623,
#  'hilarious': 624,
#  'body': 625,
#  'cool': 626,
#  'across': 627,
#  'somewhat': 628,
#  'relationship': 629,
#  'ridiculous': 630,
#  'happy': 631,
#  'usual': 632,
#  'view': 633,
#  'started': 634,
#  'level': 635,
#  'change': 636,
#  'opinion': 637,
#  'novel': 638,
#  'wish': 639,
#  'middle': 640,
#  'talking': 641,
#  'taking': 642,
#  'ones': 643,
#  'documentary': 644,
#  'robert': 645,
#  'order': 646,
#  'finds': 647,
#  'power': 648,
#  'shots': 649,
#  'female': 650,
#  'saying': 651,
#  'room': 652,
#  'huge': 653,
#  'mostly': 654,
#  'episodes': 655,
#  'country': 656,
#  'five': 657,
#  'talent': 658,
#  'important': 659,
#  'rating': 660,
#  'modern': 661,
#  'earth': 662,
#  'major': 663,
#  'word': 664,
#  'strange': 665,
#  'turned': 666,
#  'jack': 667,
#  'call': 668,
#  'apparently': 669,
#  'single': 670,
#  'disappointed': 671,
#  'four': 672,
#  'events': 673,
#  'due': 674,
#  'songs': 675,
#  'attention': 676,
#  'basically': 677,
#  'television': 678,
#  'o': 679,
#  'comic': 680,
#  'knows': 681,
#  'future': 682,
#  'clearly': 683,
#  'supporting': 684,
#  'non': 685,
#  'british': 686,
#  'knew': 687,
#  'fast': 688,
#  'thriller': 689,
#  'paul': 690,
#  'class': 691,
#  'easily': 692,
#  'cheap': 693,
#  'silly': 694,
#  'problems': 695,
#  'aren': 696,
#  'words': 697,
#  'miss': 698,
#  'tells': 699,
#  'entertainment': 700,
#  'local': 701,
#  'rock': 702,
#  'sequence': 703,
#  'bring': 704,
#  'beyond': 705,
#  'straight': 706,
#  'george': 707,
#  'oscar': 708,
#  'upon': 709,
#  'whether': 710,
#  'romantic': 711,
#  'predictable': 712,
#  'moving': 713,
#  'sets': 714,
#  'similar': 715,
#  'review': 716,
#  'eye': 717,
#  'falls': 718,
#  'mystery': 719,
#  'lady': 720,
#  'richard': 721,
#  'talk': 722,
#  'enjoyable': 723,
#  'appears': 724,
#  'needs': 725,
#  'clich': 726,
#  'giving': 727,
#  'within': 728,
#  'message': 729,
#  'ten': 730,
#  'theater': 731,
#  'animation': 732,
#  'team': 733,
#  'near': 734,
#  'red': 735,
#  'above': 736,
#  'sister': 737,
#  'sequel': 738,
#  'dull': 739,
#  'theme': 740,
#  'stand': 741,
#  'nearly': 742,
#  'points': 743,
#  'lee': 744,
#  'haven': 745,
#  'bunch': 746,
#  'mention': 747,
#  'herself': 748,
#  'york': 749,
#  'feels': 750,
#  'add': 751,
#  'release': 752,
#  'ways': 753,
#  'storyline': 754,
#  'surprised': 755,
#  'easy': 756,
#  'using': 757,
#  'e': 758,
#  'named': 759,
#  'lots': 760,
#  'fantastic': 761,
#  'begins': 762,
#  'die': 763,
#  'working': 764,
#  'actual': 765,
#  'effort': 766,
#  'feature': 767,
#  'tale': 768,
#  'minute': 769,
#  'hate': 770,
#  'french': 771,
#  'tom': 772,
#  'stay': 773,
#  'follow': 774,
#  'clear': 775,
#  'viewers': 776,
#  'among': 777,
#  'elements': 778,
#  'comments': 779,
#  'typical': 780,
#  'avoid': 781,
#  'showing': 782,
#  'editing': 783,
#  'tried': 784,
#  'season': 785,
#  'famous': 786,
#  'sorry': 787,
#  'peter': 788,
#  'fall': 789,
#  'check': 790,
#  'dialog': 791,
#  'period': 792,
#  'certain': 793,
#  'form': 794,
#  'general': 795,
#  'filmed': 796,
#  'buy': 797,
#  'soundtrack': 798,
#  'parents': 799,
#  'weak': 800,
#  'means': 801,
#  'material': 802,
#  'figure': 803,
#  'realistic': 804,
#  'somehow': 805,
#  'doubt': 806,
#  'crime': 807,
#  'space': 808,
#  'disney': 809,
#  'gone': 810,
#  'viewing': 811,
#  'kept': 812,
#  'leads': 813,
#  'th': 814,
#  'greatest': 815,
#  'dance': 816,
#  'lame': 817,
#  'suspense': 818,
#  'zombie': 819,
#  'third': 820,
#  'imagine': 821,
#  'brought': 822,
#  'atmosphere': 823,
#  'hear': 824,
#  'whatever': 825,
#  'particular': 826,
#  'de': 827,
#  'sequences': 828,
#  'america': 829,
#  'move': 830,
#  'indeed': 831,
#  'rent': 832,
#  'average': 833,
#  'eventually': 834,
#  'learn': 835,
#  'note': 836,
#  'wait': 837,
#  'reviews': 838,
#  'forget': 839,
#  'deal': 840,
#  'japanese': 841,
#  'surprise': 842,
#  'okay': 843,
#  'poorly': 844,
#  'sexual': 845,
#  'stage': 846,
#  'premise': 847,
#  'believable': 848,
#  'nature': 849,
#  'sit': 850,
#  'subject': 851,
#  'possibly': 852,
#  'decided': 853,
#  'expected': 854,
#  'imdb': 855,
#  'dr': 856,
#  'truth': 857,
#  'street': 858,
#  'became': 859,
#  'free': 860,
#  'screenplay': 861,
#  'difficult': 862,
#  'killing': 863,
#  'romance': 864,
#  'baby': 865,
#  'joe': 866,
#  'hot': 867,
#  'dog': 868,
#  'nor': 869,
#  'reading': 870,
#  'question': 871,
#  'needed': 872,
#  'leaves': 873,
#  'begin': 874,
#  'meets': 875,
#  'society': 876,
#  'directors': 877,
#  'unless': 878,
#  'credits': 879,
#  'superb': 880,
#  'otherwise': 881,
#  'shame': 882,
#  'write': 883,
#  'situation': 884,
#  'meet': 885,
#  'dramatic': 886,
#  'male': 887,
#  'memorable': 888,
#  'open': 889,
#  'earlier': 890,
#  'dream': 891,
#  'weird': 892,
#  'badly': 893,
#  'writers': 894,
#  'fi': 895,
#  'forced': 896,
#  'acted': 897,
#  'laughs': 898,
#  'sci': 899,
#  'jane': 900,
#  'emotional': 901,
#  'crazy': 902,
#  'older': 903,
#  'beauty': 904,
#  'monster': 905,
#  'realize': 906,
#  'comment': 907,
#  'deep': 908,
#  'footage': 909,
#  'forward': 910,
#  'interested': 911,
#  'fantasy': 912,
#  'ask': 913,
#  'mark': 914,
#  'whom': 915,
#  'plus': 916,
#  'sounds': 917,
#  'directing': 918,
#  'features': 919,
#  'development': 920,
#  'keeps': 921,
#  'mess': 922,
#  'c': 923,
#  'air': 924,
#  'quickly': 925,
#  'creepy': 926,
#  'box': 927,
#  'girlfriend': 928,
#  'perfectly': 929,
#  'towards': 930,
#  'worked': 931,
#  'cheesy': 932,
#  'setting': 933,
#  'unique': 934,
#  'effect': 935,
#  'bill': 936,
#  'result': 937,
#  'fire': 938,
#  'plenty': 939,
#  'hands': 940,
#  'total': 941,
#  'previous': 942,
#  'brings': 943,
#  'personal': 944,
#  'incredibly': 945,
#  'rate': 946,
#  'doctor': 947,
#  'business': 948,
#  'return': 949,
#  'joke': 950,
#  'christmas': 951,
#  'apart': 952,
#  'casting': 953,
#  'leading': 954,
#  'admit': 955,
#  'powerful': 956,
#  'background': 957,
#  'appear': 958,
#  'cop': 959,
#  'boys': 960,
#  'ben': 961,
#  'present': 962,
#  'meant': 963,
#  'telling': 964,
#  'era': 965,
#  'battle': 966,
#  'masterpiece': 967,
#  'hardly': 968,
#  'break': 969,
#  'create': 970,
#  'potential': 971,
#  'secret': 972,
#  'pay': 973,
#  'dumb': 974,
#  'political': 975,
#  'gay': 976,
#  'fighting': 977,
#  'twist': 978,
#  'fails': 979,
#  'co': 980,
#  'various': 981,
#  'portrayed': 982,
#  'villain': 983,
#  'western': 984,
#  'inside': 985,
#  'outside': 986,
#  'nudity': 987,
#  'william': 988,
#  'reasons': 989,
#  'ideas': 990,
#  'front': 991,
#  'missing': 992,
#  'match': 993,
#  'deserves': 994,
#  'married': 995,
#  'expecting': 996,
#  'rich': 997,
#  'fairly': 998,
#  'list': 999,
#  ...}

# %%
model.wv['great']
# Out:
# array([-7.6378250e-01,  2.4090033e+00,  3.5170551e-02, -6.3658200e-02,
#         4.8463216e-01,  1.2820739e+00,  3.4892768e-01, -2.0536430e+00,
#        -5.7542229e-01,  1.7094704e+00,  2.6912601e+00,  1.4359499e+00,
#        -2.7227619e+00, -2.4189845e-01,  1.9761498e+00, -4.1370978e+00,
#        -1.2178097e+00, -6.5607704e-02, -2.8954807e-01,  1.8640742e+00,
#         8.1562740e-01, -4.2445242e-01,  2.5060537e+00,  1.7694254e+00,
#        -2.7843831e+00, -1.9882702e+00,  2.2976625e+00, -3.2592826e+00,
#        -1.0717368e+00,  8.3377606e-01,  2.6410611e+00, -2.9077897e+00,
#         3.3331290e-01, -4.9895695e-01,  2.5844057e+00, -7.6500851e-01,
#        -1.3550380e+00, -1.4074228e+00,  1.8450221e+00, -2.3455739e+00,
#         2.7253613e+00, -3.3899334e-03,  9.5867682e-01, -1.3934621e+00,
#        -1.2779397e+00, -7.3306847e-01,  5.3112340e-01,  1.8975648e+00,
#        -2.9396687e+00, -2.4164038e+00], dtype=float32)

# %%
model.wv.most_similar('great',topn=15)
# Out:
# [('wonderful', 0.858059823513031),
#  ('fantastic', 0.8385528326034546),
#  ('good', 0.8208281993865967),
#  ('fine', 0.8038401007652283),
#  ('brilliant', 0.7685593366622925),
#  ('terrific', 0.7568994760513306),
#  ('nice', 0.7422287464141846),
#  ('amazing', 0.7350257635116577),
#  ('superb', 0.7092767953872681),
#  ('perfect', 0.6918379664421082),
#  ('awesome', 0.6888440847396851),
#  ('excellent', 0.6861181259155273),
#  ('marvelous', 0.6832014322280884),
#  ('spectacular', 0.6769216060638428),
#  ('remarkable', 0.6662126779556274)]

# %%
model.wv.most_similar('man',topn=15)
# Out:
# [('woman', 0.761487603187561),
#  ('guy', 0.6994047164916992),
#  ('boy', 0.6858280897140503),
#  ('person', 0.6765419840812683),
#  ('soldier', 0.6763502359390259),
#  ('lady', 0.6556635499000549),
#  ('girl', 0.6486063003540039),
#  ('doctor', 0.6297467350959778),
#  ('journalist', 0.6265723705291748),
#  ('murderer', 0.6196571588516235),
#  ('cop', 0.6060827374458313),
#  ('farmer', 0.6058788299560547),
#  ('bloke', 0.5988354086875916),
#  ('priest', 0.5907262563705444),
#  ('child', 0.5858965516090393)]

# %%
model.wv.doesnt_match(['man','woman','child','kitchen'])
# Out:
# 'kitchen'

# %%
model.save('/content/drive/MyDrive/HGN/NLP By HGN/NLP for SRM /HGN/unit2/word2vec_movi50.model')

# %%
mymodel=gensim.models.Word2Vec.load('/content/drive/MyDrive/HGN/NLP By HGN/NLP for SRM /HGN/unit2/word2vec_movi50.model')

# %%
mymodel.wv.doesnt_match(['man','woman','child','kitchen'])
# Out:
# 'kitchen'

# %%
model.wv.most_similar(positive=['king','man'],negative=['queen'])
# Out:
# [('person', 0.4652040898799896),
#  ('writer', 0.46442726254463196),
#  ('director', 0.46264421939849854),
#  ('book', 0.4585622251033783),
#  ('guy', 0.44478246569633484),
#  ('screenplay', 0.42776715755462646),
#  ('game', 0.4271361529827118),
#  ('filmmaker', 0.4264223873615265),
#  ('dorff', 0.4253430962562561),
#  ('judge', 0.4036002457141876)]

# %% [markdown]
# ## FastText

# %%
from gensim.models import FastText

# %%
# Sample tokenized sentences
documents = [
    ["deep", "learning", "is", "amazing"],
    ["fasttext", "handles", "out", "of", "vocabulary", "words"],
    ["word", "embeddings", "are", "powerful"],
    ["natural", "language", "processing", "rocks"]
]

# %%
# Train FastText model
model = FastText(
    sentences=documents,
    vector_size=50,  # Embedding size (dimensions)
    window=3,        # Context window size
    min_count=1,     # Minimum word frequency to be included in vocabulary
    workers=4,       # Number of CPU threads
    sg=1,            # 1 for Skip-gram, 0 for CBOW
    epochs=10        # Number of training epochs
)

# %%
model.wv.most_similar('great',topn=15)
# Out:
# [('wonderful', 0.8945066928863525),
#  ('terrific', 0.8909755349159241),
#  ('fine', 0.8888717293739319),
#  ('good', 0.87387615442276),
#  ('fantastic', 0.873577356338501),
#  ('fabulous', 0.8594276905059814),
#  ('fantasticfantasticfantastic', 0.8544636368751526),
#  ('superb', 0.8423476219177246),
#  ('fantabulous', 0.8405841588973999),
#  ('fantastico', 0.8324659466743469),
#  ('brilliant', 0.8166441917419434),
#  ('pluperfect', 0.8078178763389587),
#  ('superbad', 0.8053730726242065),
#  ('marvelous', 0.8031250834465027),
#  ('allsuperb', 0.8023796677589417)]

# %%
# Save and load the model
model.save("fasttext.model")
model = FastText.load("fasttext.model")

# %%
# Check vector for a word
print(model.wv["learning"])

# %% [markdown]
# ## Word Cloud

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text = " ".join(df["clean_review"].astype(str))

# Generate Word Cloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white",
    colormap="viridis",  # Change color theme if needed
    max_words=50,       # Limit words for better visualization
    stopwords=set(stopwords.words("english"))  # Exclude common English stopwords
    ).generate(text)

# %%
# Display the Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Hide axes
plt.show()
