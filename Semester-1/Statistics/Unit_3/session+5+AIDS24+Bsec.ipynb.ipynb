# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pltx
import scipy.stats as st
import statsmodels.stats as sm
import warnings
warnings.filterwarnings("ignore")

# %%
d = [1,2,3,4,5,6]

# %%
np.mean(d)
# Out:
# 3.5

# %%
np.random.choice(d)
# Out:
# 5

# %%
samp
# Out:
# [1, 6, 3, 3, 3]

# %%
np.mean(samp)
# Out:
# 3.2

# %%
trail
# Out:
# [3.6, 2.0, 3.6, 3.0, 2.4, 3.0, 2.2, 2.8, 3.2, 3.8]

# %%
np.mean(trail)
# Out:
# 3.5009999999999994

# %%
trail=[]
for j in range(100):   
    samp = []
    for i in range(5):
        samp.append(np.random.choice(d))
    trail.append(np.mean(samp))

# %%
sns.distplot(trail)
plt.vlines(x = np.mean(trail) , ymin= 0, ymax = 0.5 , colors ='r',linestyles='--' )
plt.show()

# %%
marks = np.random.randint(40,100, 1000)

# %%
np.mean(marks)
# Out:
# 69.787

# %%
trail=[]
for j in range(700):   
    samp = []
    for i in range(5):
        samp.append(np.random.choice(marks))
    trail.append(np.mean(samp))

# %%
np.mean(trail)
# Out:
# 69.58314285714285

# %%
sns.distplot(trail)
plt.vlines(x = np.mean(trail) , ymin= 0, ymax = 0.1 , colors ='r',linestyles='--' )
plt.show()

# %%
import random as rn

# %%
rn.seed(10)

# %%
sns.distplot(marks)
# Out:
# <Axes: ylabel='Density'>

# %%
Data = [49.8, 52.3, 51, 56.9, 54.8, 63, 58.2, 54.1, 50.4, 49.2, 47, 51.3, 43.5, 56, 55]

# %%
np.mean(Data)
# Out:
# 52.833333333333336

# %%
n = 250
xbar = 45000
s =  4000
zalphaby2=1.96

ME =  zalphaby2 * s/np.sqrt(n) 
ME


se = s/np.sqrt(n)
# Out:
# 495.8451371144019

# %%
lci =  xbar- ME
uci = xbar+ME

print(lci,uci)
# Out:
# 44504.154862885596 45495.845137114404

# %%
se = s/np.sqrt(n)

# %%
st.norm.interval(0.95, loc = xbar, scale = se )
# Out:
# (44504.16397415635, 45495.83602584365)

# %%
st.norm.interval(0.90, loc = xbar, scale = se )
# Out:
# (44583.88128969955, 45416.11871030045)

# %%
st.norm.interval(0.99, loc = xbar, scale = se )
# Out:
# (44348.361002958416, 45651.638997041584)

# %%
n=13
p = 8/13
zalphaby2 = 2.575
ME = (zalphaby2 * (np.sqrt(p*(1-p))/n))

# %%
ME
# Out:
# 0.0963652659755453

# %%
lci = p-ME
uci = p+ME
lci,uci
# Out:
# (0.5190193494090701, 0.7117498813601607)

# %%
p
# Out:
# 0.6153846153846154

# %%
st.norm.interval(0.99, loc = p , scale = np.sqrt(p*(1-p))/n )
# Out:
# (0.5189883140471034, 0.7117809167221274)

# %%
st.norm.isf(0.99)
# Out:
# -2.3263478740408408

# %%
st.norm.ppf(0.99)
# Out:
# 2.3263478740408408
