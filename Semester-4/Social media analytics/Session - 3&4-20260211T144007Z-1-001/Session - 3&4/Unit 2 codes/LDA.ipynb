# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

documents = [
    "I love machine learning and NLP",
    "AI and deep learning are powerful",
    "Politics and elections dominate news",
    "Government announces new policy",
    "Football match was exciting"
]

# Step 1: Convert text to Bag of Words
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# Step 2: Train LDA model
lda = LatentDirichletAllocation(n_components=2, random_state=42)
lda.fit(X)

print("LDA Model Trained Successfully")
# Out:
# LDA Model Trained Successfully

# %%
import numpy as np

feature_names = vectorizer.get_feature_names_out()

for topic_idx, topic in enumerate(lda.components_):
    print(f"\nTopic {topic_idx}:")
    top_words = topic.argsort()[-5:]
    print([feature_names[i] for i in top_words])
# Out:
# Topic 0:
# ['government', 'politics', 'dominate', 'news', 'elections']
#
# Topic 1:
# ['love', 'ai', 'deep', 'powerful', 'learning']

# %%
doc_topics = lda.transform(X)

print(doc_topics)
# Out:
# [[0.10454519 0.89545481]
#  [0.10454516 0.89545484]
#  [0.89639068 0.10360932]
#  [0.89639068 0.10360932]
#  [0.1316448  0.8683552 ]]
