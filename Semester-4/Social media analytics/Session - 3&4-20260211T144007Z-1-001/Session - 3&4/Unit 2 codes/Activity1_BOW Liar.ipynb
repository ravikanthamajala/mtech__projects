# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

texts=["good movie","bad movie","good food","bad food"]
labels=[1,0,1,0]

texts=[t+" xyz" for t in texts]

cv=CountVectorizer()
X=cv.fit_transform(texts)

print("Injected word:",max(cv.vocabulary_,key=lambda x:cv.vocabulary_[x]))
# Out:
# Injected word: xyz
