# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

texts = [
    "I love this phone",
    "Worst product ever",
    "Amazing camera quality",
    "Battery life is terrible",
    "Very happy with this purchase",
    "I hate this service"
]

labels = [1, 0, 1, 0, 1, 0]   # 1 = Positive, 0 = Negative

# TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# Train SVM on all data (demo purpose)
svm_model = LinearSVC()
svm_model.fit(X, labels)

# New test sentences
test_sentences = [
    "I love this camera",
    "This service is terrible",
    "Very happy with phone",
    "Worst experience"
]

X_test = vectorizer.transform(test_sentences)

predictions = svm_model.predict(X_test)

# Convert 0/1 into words
for sent, pred in zip(test_sentences, predictions):
    sentiment = "Positive" if pred == 1 else "Negative"
    print(sent, "→", sentiment)
# Out:
# I love this camera → Positive
# This service is terrible → Negative
# Very happy with phone → Positive
# Worst experience → Negative
